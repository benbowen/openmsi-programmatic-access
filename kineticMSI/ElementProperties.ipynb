# %%
from periodictable import elements, formula

# %%
print dir(elements.C)
# Out:
# ['K_alpha', 'K_alpha_units', 'K_beta1', 'K_beta1_units', '__class__', '__delattr__', '__dict__', '__doc__', '__format__', '__getattribute__', '__getitem__', '__hash__', '__init__', '__iter__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_density', '_isotopes', '_mass', 'abundance_units', 'add_isotope', 'charge', 'covalent_radius', 'covalent_radius_uncertainty', 'covalent_radius_units', 'crystal_structure', 'density', 'density_caveat', 'density_units', 'interatomic_distance', 'interatomic_distance_units', 'ion', 'ions', 'isotopes', 'magnetic_ff', 'mass', 'mass_units', 'name', 'neutron', 'number', 'number_density', 'number_density_units', 'symbol', 'table', 'xray']

# %%
L = ['H','C','N']
for e in elements:
#     print e.symbol
    for i in getattr(elements,e.symbol):
        if getattr(i,'abundance') > 0:
            t = "%s %2.5f %5.8f" % (e,getattr(i,'abundance'),getattr(i,'mass'))
            print t
# Out:
# n 100.00000 1.00866492
# H 99.98850 1.00782503
# H 0.01150 2.01410178
# He 0.00014 3.01602931
# He 99.99986 4.00260325
# Li 7.59000 6.01512230
# Li 92.41000 7.01600400
# Be 100.00000 9.01218210
# B 19.90000 10.01293700
# B 80.10000 11.00930550
# C 98.93000 12.00000000
# C 1.07000 13.00335484
# N 99.63200 14.00307401
# N 0.36800 15.00010890
# O 99.75700 15.99491462
# O 0.03800 16.99913150
# O 0.20500 17.99916040
# F 100.00000 18.99840320
# Ne 90.48000 19.99244018
# Ne 0.27000 20.99384674
# Ne 9.25000 21.99138551
# Na 100.00000 22.98976967
# Mg 78.99000 23.98504190
# Mg 10.00000 24.98583702
# Mg 11.01000 25.98259304
# Al 100.00000 26.98153844
# Si 92.22970 27.97692653
# Si 4.68320 28.97649472
# Si 3.08720 29.97377022
# P 100.00000 30.97376151
# S 94.93000 31.97207069
# S 0.76000 32.97145850
# S 4.29000 33.96786683
# S 0.02000 35.96708088
# Cl 75.78000 34.96885271
# Cl 24.22000 36.96590260
# Ar 0.33650 35.96754628
# Ar 0.06320 37.96273220
# Ar 99.60030 39.96238312
# ...

# %%
from periodictable import formula, mix_by_volume, mix_by_weight
H2O = formula('H2O',natural_density=1)
H2O.atoms
# Out:
# {H: 2, O: 1}

# %%
t = 'name'
getattr(elements.C,t)

L = dir(elements.C)
print L[43]

getattr(elements.C,L[43])

print L[10][0]
# Out:
# mass
# _

# %%
list(elements.C)
# for i in elements.C:
#     print i
#     print i.abundance
#     print i.mass
#     print i.isotope
# Out:
# [C[8],
#  C[9],
#  C[10],
#  C[11],
#  C[12],
#  C[13],
#  C[14],
#  C[15],
#  C[16],
#  C[17],
#  C[18],
#  C[19],
#  C[20],
#  C[21],
#  C[22]]

# %%
for iso in elements.H:
    print("%s %s"%(iso,iso.mass))
# Out:
# 1-H 1.0078250321
# D 2.014101778
# T 3.0160492675
# 4-H 4.02783
# 5-H 5.03954
# 6-H 6.04494
