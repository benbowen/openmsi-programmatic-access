# %%
import requests, json
client = requests.Session()

# %%
url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/%d/JSON' % (10607)
r = client.get(url)
data = json.loads(r.content)
print data
# Out:
# {u'PC_Compounds': [{u'count': {u'isotope_atom': 0, u'covalent_unit': 1, u'heavy_atom': 30, u'atom_chiral': 4, u'bond_chiral_undef': 0, u'bond_chiral_def': 0, u'bond_chiral': 0, u'atom_chiral_undef': 0, u'atom_chiral_def': 4, u'tautomers': 2}, u'stereo': [{u'tetrahedral': {u'parity': u'clockwise', u'center': 9, u'bottom': 14, u'top': 12, u'below': 31, u'above': 10, u'type': u'tetrahedral'}}, {u'tetrahedral': {u'parity': u'clockwise', u'center': 10, u'bottom': 16, u'top': 11, u'below': 32, u'above': 9, u'type': u'tetrahedral'}}, {u'tetrahedral': {u'parity': u'clockwise', u'center': 11, u'bottom': 17, u'top': 13, u'below': 33, u'above': 10, u'type': u'tetrahedral'}}, {u'tetrahedral': {u'parity': u'counterclockwise', u'center': 12, u'bottom': 9, u'top': 15, u'below': 34, u'above': 2, u'type': u'tetrahedral'}}], u'bonds': {u'aid2': [14, 16, 12, 39, 16, 20, 27, 21, 27, 24, 28, 25, 29, 26, 30, 10, 12, 14, 31, 11, 16, 32, 13, 17, 33, 15, 34, 15, 18, 35, 36, 19, 22, 23, 20, 37, 21, 38, 21, 25
# ...
